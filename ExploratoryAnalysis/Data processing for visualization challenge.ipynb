# %% [markdown]
# The goal of this script is to process the data for data visulization challenge. For the visualization, I will develop a shiny app that displays the following information:
#
# - for each department
# - for male and female
# - for highest rating and lowest rating
#
# **Display the 50 most relavent words in wordcloud.**

# %% [markdown]
# Since the shiny app can't load too much data, I will preprocess the data here and save the compact information for later.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# %%
train = pd.read_csv("../Data/train.csv")

# %%
# later probably will drop some columns
print train.columns
# Out:
# Index([u'id', u'tid', u'dept', u'date', u'forcredit', u'attendance',
#        u'textbookuse', u'interest', u'grade', u'tags', u'comments',
#        u'helpcount', u'nothelpcount', u'online', u'profgender', u'profhotness',
#        u'helpfulness', u'clarity', u'easiness', u'quality'],
#       dtype='object')

# %% [markdown]
# Now let me take a look at `comments` column.

# %%
# Now let's take a look at the `comments` column
stop_words = './stop_words.txt'
with open(stop_words, 'r') as f:
    words = f.read()
    words = words.split('\n')[:-1]
# Create a CountVectorizer object and use the fit_transform method to learn the document-term matrix.
count_vec = CountVectorizer(min_df=120, ngram_range=(1,2), stop_words=words)
doc_word_matrix = count_vec.fit_transform(train['comments'].fillna(''))

# %%
# DataFrame objects can be created from dictionaries.  We start by initializing a dictionary
# that has just the ids corresponding to comments.
freq_dict = {'id':train.id}
count = 0

# The count_vec object stores the words from the text as a list.  Word i corresponds to index i.
for word in count_vec.get_feature_names():
    # Pull a column from the document-term matrix and assign it to its corresponding word
    # in the dictionary.
    freq_dict[word] = doc_word_matrix[:,count].toarray().T[0]  # I admit it, this looks hacky and gross.
    count+=1
    
# Create a new DataFrame object with the dictionary we created.  This will be much easier to search
# and analyze later.
doc_word_df = pd.DataFrame(data=freq_dict)

# %% [markdown]
# Now, I have the original data and processed comments ready.

# %%
# Find duplicate rows.  Based on my observations, a duplicate of a row always immediately follows the row of which it 
# is a copy.  Thus, we will go row by row and see if any two subsequent ids are the same.  If so, we will add the 
# index of the id to a list for future removal.
duplicates = []
for i in range(len(doc_word_df)-1):
    if doc_word_df['id'][i] == doc_word_df['id'][i+1]:
        duplicates.append(i)

# %%
# drop the duplciates
train.drop(duplicates, inplace = True)
doc_word_df.drop(duplicates, inplace = True)

# %%
for each_dept in train.dept.unique():
    print each_dept, ':', train.ix[train.dept == each_dept].shape[0]
# Out:
# Business : 4200
# Economics : 4926
# Religion : 9417
# Church History : 390
# Social Science : 850
# Anthropology : 1563
# Accounting : 1764
# Music : 1446
# Psychology : 5012
# Chemistry : 9343
# Theater : 895
# Biology : 7989
# Fine Arts : 964
# History : 4817
# Political Science : 4506
# Science : 2743
# Interior Design : 104
# Humanities : 1788
# Mathematics : 9391
# Statistics : 679
# Art : 499
# Physiology : 149
# Agriculture : 413
# Geography : 1387
# Spanish : 534
# Physics : 3106
# Sociology : 3308
# Family & Consumer Science : 175
# Writing : 316
# Film : 244
# Philosophy : 1444
# Communication : 2054
# Computer Science : 2007
# Nutrition & Food Science : 95
# English : 6637
# Finance : 398
# Japanese : 91
# Geology : 1071
# Engineering : 2530
# Marriage Family & Human Dev : 49
# Languages : 2673
# Physical Sciences : 129
# Dance : 253
# Student Services : 150
# French : 95
# Health Science : 902
# Classical Studies : 37
# Literature : 797
# English Language & Literature : 61
# Information Systems : 280
# Mathematics Education : 60
# Classics : 537
# Exercise & Sport Science : 229
# Microbiology : 108
# Communication Disorders : 167
# Physical Education : 86
# Health & Physical Education : 44
# Russian : 61
# Art History : 340
# Foreign Languages : 51
# School of Family Life : 29
# German : 149
# Visual Arts : 82
# Linguistics : 145
# Family Studies : 57
# Social Work : 339
# Asian & Near Eastern Languages : 18
# Chemical Engineering : 61
# Business Administration : 31
# Human Development : 49
# Exercise Science : 38
# Chinese : 50
# Honors : 15
# Mechanical Engineering : 213
# Molecular Biosciences : 21
# Early Childhood Education : 15
# International Studies : 328
# Italian : 24
# Theatre & Media Arts : 22
# Civil Engineering : 77
# Electrical Engineering : 82
# Medicine : 254
# Law : 350
# Secondary Education : 16
# Recreation : 29
# Management : 208
# Physical Ed : 147
# Hebrew : 9
# Korean : 9
# Information Technology : 12
# Ancient Scripture : 9
# Scandinavian : 96
# Industrial Design : 16
# Elementary Education : 13
# Educational Leadership : 8
# French & Italian : 24
# Technology : 7
# Education : 663
# Arabic : 41
# Portuguese : 5
# Nursing : 120
# Organizational Ldrshp  Strat : 5
# Not Specified : 117
# Life Science : 4
# Criminal Justice : 99
# Nutrition  Food Science : 3
# University Studies : 2
# Latin American Studies : 1
# Aerospace Studies : 9
# Marketing : 353
# Women's Studies : 277
# Journalism : 889
# Ethnic Studies : 160
# Art & Art History : 180
# East Asian Studies : 38
# Theology : 527
# Genetics : 73
# Zoology : 154
# Spanish & Portuguese : 192
# Asian Studies : 16
# Environmental Studies : 24
# Pharmacy : 69
# Agricultural Economics : 12
# Design : 137
# Consumer Science : 18
# Nutrition : 27
# Kinesiology : 158
# East Asian Lang. & Literature : 6
# Rehabilitation Psychology : 9
# African Studies : 55
# Astronomy : 179
# Military Science : 16
# Oncology : 1
# Biomedical Engineering : 1
# Horticulture : 349
# Mathematical and Computer Sci. : 91
# Religious Studies : 66
# Foreign Languages & Literature : 328
# Computer Information Technology : 48
# Child & Family Studies : 243
# Business Management : 44
# Animal Science : 111
# Home & Family Studies : 38
# Academic Services : 33
# Architecture : 297
# Automotive Technology : 30
# Career & College Prep : 13
# Online Learning : 38
# Career Development : 8
# Latin : 15
# Health & Human Performance : 5
# General Studies : 2
# Library Science : 1
# Cultural Studies : 294
# Physics & Astronomy : 224
# Family Social Science : 107
# Materials Science : 102
# Genetics / Cell Biology & Dev. : 46
# Biological Sciences : 89
# Sign Language : 29
# Organizational Leadership : 24
# Human Resources : 28
# Graphic Arts : 36
# Speech/Language/Hearing Sci. : 34
# Communication Studies : 37
# Gender, Women, and Sex Studies : 43
# Educational Psychology : 21
# Information Decision Sciences : 15
# Chicano Studies : 19
# African-American Studies : 42
# Writing Studies : 61
# Curriculum & Instruction : 19
# Child Development : 17
# Asian Languages & Literatures : 12
# Food Science & Nutrition : 25
# Sports Management : 11
# Electrical & Comp. Engineering : 12
# Aerospace Eng. & Mechanics : 11
# Natural History : 5
# German & Scandinavian : 5
# Rhetoric : 5
# Center for Spiritual Health : 5
# Administration : 1
# Public Affairs : 1
# Theatre Arts & Dance : 1
# Anatomy : 64
# Art Education : 68
# Textiles & Clothing : 61
# Food Science : 41
# Comparative Studies : 30
# Biochemistry : 22
# Engineering Graphics Tech. : 32
# Hospitality Management : 19
# Environ. & Natural Resources : 41
# Industrial Engineering : 37
# Allied Health : 16
# Hospitality : 15
# Natural Resources : 15
# Aerospace Engineering : 23
# Speech & Hearing Sciences : 22
# Human Resource Management : 26
# Human Ecology : 10
# Persian : 9
# Near Eastern Studies : 16
# Public Policy : 15
# Agricultural Engineering : 6
# Slavic Languages : 4
# Public Administration : 6
# Neuroscience : 4
# Sports : 3
# Greek : 5
# Aviation : 3
# Public Health : 3
# Transportation & Logistics : 2
# Education & Human Ecology : 1

# %% [markdown]
# Above results shows that we need to group different departments together to have enough sample to do regression for each department. Next, we are going to output the department in the train.csv and group them according to the one we see on that New Yorker website.

# %%
fout = open('all_depts.csv', 'w')
for each_dept in train.dept.unique():
    fout.write(each_dept + ',' + str(train.ix[train.dept == each_dept].shape[0]) + '\n')
fout.close()

# %% [markdown]
# I manually divide above departments in to the following categories, which I saved in `grouped depts.txt`. Next I will read the file and add a new columns that map the current departments to divided departments.

# %%
# we notice that there is a department called 'Gender, Women, and Sex Studies'. For later to separate each department in a
# group, we need use ',' to split the row string. So, we are going to change it to 'Gender_Women_and Sex Studies'

train.ix[train.dept == 'Gender, Women, and Sex Studies', 'dept'] = 'Gender_Women_and Sex Studies'
train.ix[train.dept =='Gender_Women_and Sex Studies']
# Out:
#              id      tid                          dept        date forcredit  \
# 83444  24317131  1522784  Gender_Women_and Sex Studies  01/21/2015       Yes
# 83445  24296609  1522784  Gender_Women_and Sex Studies  01/16/2015       Yes
# 83446  23995183  1522784  Gender_Women_and Sex Studies  12/09/2014       Yes
# 83447  23519233  1522784  Gender_Women_and Sex Studies  08/11/2014       NaN
# 83448  23341363  1522784  Gender_Women_and Sex Studies  06/03/2014       NaN
# 83449  23308365  1522784  Gender_Women_and Sex Studies  05/24/2014       NaN
# 83450  23257620  1522784  Gender_Women_and Sex Studies  05/15/2014       NaN
# 83451  22989872  1522784  Gender_Women_and Sex Studies  04/04/2014       NaN
# 83452  21620994  1522784  Gender_Women_and Sex Studies  04/28/2013       NaN
# 83453  21527884  1522784  Gender_Women_and Sex Studies  04/12/2013       NaN
# 83454  21181041  1522784  Gender_Women_and Sex Studies  12/28/2012       NaN
# 83455  20965549  1522784  Gender_Women_and Sex Studies  12/05/2012       NaN
# 83456  20535726  1522784  Gender_Women_and Sex Studies  08/01/2012       NaN
# 83457  20239857  1522784  Gender_Women_and Sex Studies  05/09/2012       NaN
# 83458  19789107  1522784  Gender_Women_and Sex Studies  01/31/2012       NaN
# 83459  19502744  1522784  Gender_Women_and Sex Studies  12/14/2011       NaN
# 83460  19484835  1522784  Gender_Women_and Sex Studies  12/13/2011       NaN
# 83461  19066873  1522784  Gender_Women_and Sex Studies  10/12/2011       NaN
# 83462  18659362  1522784  Gender_Women_and Sex Studies  05/24/2011       NaN
# 86640  22771114  1813246  Gender_Women_and Sex Studies  01/19/2014       NaN
# 86641  22771088  1813246  Gender_Women_and Sex Studies  01/19/2014       NaN
# 86642  22531923  1813246  Gender_Women_and Sex Studies  12/12/2013       NaN
# 86643  22424011  1813246  Gender_Women_and Sex Studies  12/03/2013       NaN
# 86644  22176577  1813246  Gender_Women_and Sex Studies  10/14/2013       NaN
# 86645  22176572  1813246  Gender_Women_and Sex Studies  10/14/2013       NaN
# 86646  22171379  1813246  Gender_Women_and Sex Studies  10/10/2013       NaN
# 86647  21622737  1813246  Gender_Women_and Sex Studies  04/28/2013       NaN
# 87328  24308586  1512215  Gender_Women_and Sex Studies  01/20/2015       Yes
# 87329  23247540  1512215  Gender_Women_and Sex Studies  05/14/2014       NaN
# 87330  23134730  1512215  Gender_Women_and Sex Studies  04/30/2014       NaN
# 87331  22644477  1512215  Gender_Women_and Sex Studies  12/23/2013       NaN
# 87332  22603296  1512215  Gender_Women_and Sex Studies  12/18/2013       NaN
# 87333  22423633  1512215  Gender_Women_and Sex Studies  12/03/2013       NaN
# 87545  23560491  1762327  Gender_Women_and Sex Studies  08/27/2014       NaN
# 87546  22619200  1762327  Gender_Women_and Sex Studies  12/19/2013       NaN
# 87547  21022471  1762327  Gender_Women_and Sex Studies  12/11/2012       NaN
# 87548  20921260  1762327  Gender_Women_and Sex Studies  11/30/2012       NaN
# 87549  20814235  1762327  Gender_Women_and Sex Studies  11/11/2012       NaN
# 87560  23980693  1813250  Gender_Women_and Sex Studies  12/08/2014       Yes
# 87561  22491026  1813250  Gender_Women_and Sex Studies  12/10/2013       NaN
# 87562  22255415  1813250  Gender_Women_and Sex Studies  11/04/2013       NaN
# 87563  21940489  1813250  Gender_Women_and Sex Studies  07/02/2013       NaN
# 87564  21821952  1813250  Gender_Women_and Sex Studies  05/24/2013       NaN
#
#           attendance             textbookuse          interest grade  \
# 83444  Not Mandatory    Essential to passing      It's my life     A
# 83445            NaN   You need it sometimes    Really into it   NaN
# 83446  Not Mandatory   You need it sometimes               Low   NaN
# 83447            NaN   You need it sometimes  Sorta interested   NaN
# 83448            NaN  Barely cracked it open      It's my life   NaN
# 83449  Not Mandatory    Essential to passing      It's my life   NaN
# 83450            NaN   You need it sometimes               Low   NaN
# 83451      Mandatory    Essential to passing    Really into it   NaN
# 83452            NaN    Essential to passing    Really into it   NaN
# 83453            NaN    Essential to passing               Low   NaN
# 83454            NaN    Essential to passing    Really into it   NaN
# 83455            NaN    Essential to passing    Really into it   NaN
# 83456            NaN        It's a must have               Low   NaN
# 83457            NaN  Barely cracked it open               Low   NaN
# 83458            NaN   You need it sometimes      It's my life   NaN
# 83459            NaN        It's a must have    Really into it   NaN
# 83460            NaN  Barely cracked it open  Sorta interested   NaN
# 83461            NaN        It's a must have  Sorta interested   NaN
# 83462            NaN        It's a must have    Really into it   NaN
# 86640      Mandatory    Essential to passing               Low   NaN
# 86641      Mandatory          What textbook?  Sorta interested   NaN
# 86642      Mandatory          What textbook?  Sorta interested     P
# 86643      Mandatory          What textbook?               Low     P
# 86644      Mandatory          What textbook?    Really into it    B+
# 86645      Mandatory          What textbook?      It's my life   NaN
# 86646            NaN          What textbook?               Meh   NaN
# 86647            NaN  Barely cracked it open    Really into it   NaN
# 87328  Not Mandatory   You need it sometimes      It's my life     A
# 87329      Mandatory   You need it sometimes  Sorta interested    B+
# 87330  Not Mandatory   You need it sometimes    Really into it     A
# 87331      Mandatory   You need it sometimes               Low   NaN
# 87332            NaN   You need it sometimes    Really into it   NaN
# 87333            NaN  Barely cracked it open               Meh   NaN
# 87545      Mandatory        It's a must have    Really into it    B+
# 87546      Mandatory          What textbook?  Sorta interested   NaN
# 87547            NaN    Essential to passing      It's my life   NaN
# 87548            NaN          What textbook?  Sorta interested   NaN
# 87549            NaN    Essential to passing               Meh   NaN
# 87560            NaN          What textbook?    Really into it   NaN
# 87561            NaN    Essential to passing    Really into it   NaN
# 87562  Not Mandatory    Essential to passing  Sorta interested     A
# 87563            NaN        It's a must have    Really into it   NaN
# 87564            NaN    Essential to passing               Low   NaN
#
#                                                     tags  \
# 83444  ["Would take again", "Inspirational", "Gives g...
# 83445  ["Inspirational", "Participation matters", "Th...
# 83446  ["Better Like Group Projects", "Get ready to r...
# 83447                                                 []
# 83448                                                 []
# 83449                                                 []
# 83450                                                 []
# 83451                                                 []
# 83452                                                 []
# 83453                                                 []
# 83454                                                 []
# 83455                                                 []
# 83456                                                 []
# 83457                                                 []
# 83458                                                 []
# 83459                                                 []
# 83460                                                 []
# 83461                                                 []
# 83462                                                 []
# 86640                                                 []
# 86641                                                 []
# 86642                                                 []
# 86643                                                 []
# 86644                                                 []
# 86645                                                 []
# 86646                                                 []
# 86647                                                 []
# 87328  ["There for you", "Participation matters", "Gi...
# 87329                                                 []
# 87330                                                 []
# 87331                                                 []
# 87332                                                 []
# 87333                                                 []
# 87545                                                 []
# 87546                                                 []
# 87547                                                 []
# 87548                                                 []
# 87549                                                 []
# 87560  ["Gives good feedback", "Get ready to read", "...
# 87561                                                 []
# 87562                                                 []
# 87563                                                 []
# 87564                                                 []
#
#                                                 comments  helpcount  \
# 83444  Prof Isoke is incredible Taking class from her...          0
# 83445  Lots of individualized attention in office hou...          0
# 83446  Professor Isoke is very unorganized and change...          0
# 83447  DO NOT TAKE THIS CLASS She is very unorganized...          0
# 83448  Zenzele is very hard to get ahold of often ref...          0
# 83449                                              Great          0
# 83450  NEVER TAKE THIS CLASS While I was very interes...          0
# 83451  Its an easy class Getting As on papers and tes...          0
# 83452  While I feel like this class is very repetitiv...          0
# 83453  Isoke knows her stuff She knows the field and ...          0
# 83454  This would be the second time I took a class w...          0
# 83455  Isoke is a pretty good professor Do the readin...          0
# 83456  This class was fun The assignments were good a...          0
# 83457  The class was taught from a very biased point ...          0
# 83458  This was my favorite course Professor Isokes t...          0
# 83459  Class discussions were interesting but she oft...          0
# 83460  Disorganized and unclear about what to do for ...          0
# 83461  A lot of great discussion Powerpoints helpful ...          0
# 83462  Great readings Zenzele has a great sense of hu...          0
# 86640  I had very little interest in the topic before...          0
# 86641  This professor takes class participation serio...          0
# 86642  Grading based entirely on whether or not she l...          0
# 86643  She wants class participating and takes attend...          0
# 86644  I used to be a strong believer in the feminist...          0
# 86645  Every moment I spent in her class I slowly die...          0
# 86646                         Would give a 0 if possible          0
# 86647  Brittany was very interested in class and a ve...          0
# 87328  This was one of the best classes Ive taken at ...          0
# 87329  Made MOVIES dull dull dull I can watch movies ...          0
# 87330  Pretty good class We watched a lot of films I ...          0
# 87331  Attendance was mandatory which is idiotic Lots...          0
# 87332  I actually liked the class The films we watche...          0
# 87333  So incredibly boring Jessica seems very nervou...          0
# 87545  Very nice professor Down to earth and understa...          0
# 87546  Dr Craddock is phenomenal Extremely intelligen...          0
# 87547  I was very excited about this class and had ve...          0
# 87548  Pretty much the opposite of what you could hop...          0
# 87549  Didnt think I would enjoy this class at all bu...          0
# 87560  One of my all time favorite teachers She expla...          0
# 87561  She is such a friendly and kind teacher The cl...          0
# 87562  Fabulous class I am not in the feminist studie...          0
# 87563  I actually really loved this class Feminist Sc...          0
# 87564  Interesting professor Was very nice some days ...          0
#
#        nothelpcount online  profgender  profhotness  helpfulness  clarity  \
# 83444             0    NaN           0            0            5        4
# 83445             0    NaN           0            0            4        3
# 83446             0    NaN           0            0            2        2
# 83447             0    NaN           0            0            1        1
# 83448             0    NaN           0            0            2        2
# 83449             0    NaN           0            0            5        5
# 83450             0    NaN           0            0            1        1
# 83451             0    NaN           0            0            3        2
# 83452             0    NaN           0            0            5        4
# 83453             1    NaN           0            0            5        5
# 83454             0    NaN           0            0            5        4
# 83455             0    NaN           0            0            3        3
# 83456             0    NaN           0            0            5        4
# 83457             0    NaN           0            0            2        2
# 83458             0    NaN           0            0            5        5
# 83459             0    NaN           0            0            3        3
# 83460             0    NaN           0            0            2        3
# 83461             0    NaN           0            0            5        4
# 83462             0    NaN           0            0            5        4
# 86640             0    NaN           1            0            5        4
# 86641             0    NaN           1            0            5        3
# 86642             0    NaN           1            0            1        1
# 86643             0    NaN           1            0            3        4
# 86644             0    NaN           1            0            1        1
# 86645             0    NaN           1            0            1        1
# 86646             0    NaN           1            0            1        1
# 86647             0    NaN           1            0            5        4
# 87328             0    NaN           1            0            5        5
# 87329             0    NaN           1            0            1        1
# 87330             0    NaN           1            0            5        4
# 87331             0    NaN           1            0            3        2
# 87332             0    NaN           1            0            5        4
# 87333             0    NaN           1            0            2        1
# 87545             0    NaN           1            0            5        4
# 87546             0    NaN           1            0            5        5
# 87547             0    NaN           1            0            2        4
# 87548             0    NaN           1            0            1        1
# 87549             0    NaN           1            0            5        5
# 87560             0    NaN           1            1            5        4
# 87561             0    NaN           1            1            5        5
# 87562             0    NaN           1            1            5        4
# 87563             0    NaN           1            1            5        5
# 87564             0    NaN           1            1            4        5
#
#        easiness  quality
# 83444         3        9
# 83445         2        7
# 83446         3        4
# 83447         3        2
# 83448         4        4
# 83449         5       10
# 83450         3        2
# 83451         5        5
# 83452         5        9
# 83453         3       10
# 83454         5        9
# 83455         5        6
# 83456         4        9
# 83457         2        4
# 83458         5       10
# 83459         4        6
# 83460         3        5
# 83461         3        9
# 83462         4        9
# 86640         5        9
# 86641         4        8
# 86642         2        2
# 86643         3        7
# 86644         1        2
# 86645         1        2
# 86646         1        2
# 86647         4        9
# 87328         4       10
# 87329         3        2
# 87330         4        9
# 87331         4        5
# 87332         4        9
# 87333         2        3
# 87545         3        9
# 87546         4       10
# 87547         3        6
# 87548         4        2
# 87549         3       10
# 87560         4        9
# 87561         5       10
# 87562         3        9
# 87563         3       10
# 87564         3        9

# %%
# create a department mapping dictionary
dept_mapping = {}
f = open("grouped depts.txt")
for line in f:
    temp_div = line.split(': ')
    dept_group = temp_div[0]
    temp_depts = temp_div[1].strip('\n')
    for temp_dept in temp_depts.split(', '):
        dept_mapping[temp_dept] = dept_group
f.close()
print dept_mapping
# Out:
# {'': 'Accounting', 'Education & Human Ecology': 'Humanities', 'Business Administration': 'Business', 'Biochemistry': 'Biology', 'Sign Language': 'Communication', 'Human Resources': 'Business', 'Microbiology': 'Biology', 'Physical Sciences': 'Science', 'Religion': 'Religion', 'Family Social Science': 'Sociology', 'Engineering Graphics Tech.': 'Engineering', 'Business': 'Business', 'Fine Arts': 'Arts', 'Consumer Science': 'Business', 'Library Science': 'Science', 'Environmental Studies': 'Engineering', 'French': 'Languages', 'Anthropology': 'Anthropology', 'Marriage Family & Human Dev': 'Sociology', 'Exercise & Sport Science': 'Science', 'Computer Science': 'Computer Science', 'Life Science': 'Biology', 'Physical Education': 'Education', 'Writing Studies': 'Communication', 'Public Health': 'Health Science', 'Curriculum & Instruction': 'Education', 'Family & Consumer Science': 'Sociology', 'Theatre Arts & Dance': 'Arts', 'Health & Physical Education': 'Education', 'Kinesiology': 'Health Science', 'Family Studies': 'Sociology', 'Classics': 'Literature', 'Sports': 'Other', 'Automotive Technology': 'Engineering', 'Italian': 'Languages', 'Oncology': 'Biology', 'Art': 'Arts', 'Nursing': 'Health Science', 'Textiles & Clothing': 'Arts', 'Food Science': 'Agriculture and Food Sciences', 'Early Childhood Education': 'Education', 'Business Management': 'Business', 'Social Work': 'Sociology', 'Ethnic Studies': 'Sociology', 'Electrical Engineering': 'Engineering', 'Gender_Women_and Sex Studies': 'Sociology', 'Education': 'Education', 'Agriculture': 'Agriculture and Food Sciences', 'Agricultural Engineering': 'Agriculture and Food Sciences', 'Materials Science': 'Science', 'Statistics': 'Mathmatics', 'Art & Art History': 'Arts', 'Philosophy ': 'Philosophy', 'Pharmacy': 'Health Science', 'Animal Science': 'Science', "Women's Studies": 'Sociology', 'Human Ecology': 'Humanities', 'General Studies': 'Other', 'Biology': 'Biology', 'Latin': 'Languages', 'Physical Ed': 'Education', 'Not Specified': 'Other', 'Marketing': 'Business', 'Interior Design': 'Arts', 'School of Family Life': 'Sociology', 'Aviation': 'Engineering', 'Astronomy': 'Physics', 'Elementary Education': 'Education', 'Rhetoric': 'Communication', 'Human Resource Management': 'Business', 'Theater': 'Arts', 'Economics': 'Economics', 'Scandinavian': 'Anthropology', 'Greek': 'Languages', 'Architecture': 'Arts', 'English': 'English', 'Hospitality': 'Business', 'Electrical & Comp. Engineering': 'Computer Science', 'Chemistry': 'Chemistry', 'Biomedical Engineering': 'Engineering', 'Computer Information Technology': 'Computer Science', 'Physics & Astronomy': 'Physics', 'Religious Studies': 'Religion', 'Public Administration': 'Political Science', 'Dance': 'Arts', 'Communication': 'Communication', 'Industrial Engineering': 'Engineering', 'Geology': 'Science', 'Criminal Justice': 'Law', 'Civil Engineering': 'Engineering', 'Design': 'Engineering', 'Church History': 'Religion', 'Natural History': 'History', 'Arabic': 'Languages', 'Technology': 'Engineering', 'Honors': 'Other', 'Linguistics': 'Languages', 'Theatre & Media Arts': 'Arts', 'Genetics': 'Biology', 'Psychology': 'Psychology', 'Humanities': 'Humanities', 'Biological Sciences': 'Biology', 'Administration': 'Business', 'Writing': 'Communication', 'Languages': 'Languages', 'Near Eastern Studies': 'Sociology', 'Management': 'Business', 'Music': 'Music', 'German & Scandinavian': 'Languages', 'Political Science': 'Political Science', 'Medicine': 'Health Science', 'Career & College Prep': 'Other', 'Korean': 'Languages', 'Rehabilitation Psychology': 'Psychology', 'Mathematics Education': 'Education', 'Nutrition': 'Agriculture and Food Sciences', 'East Asian Studies': 'Sociology', 'Literature': 'Literature', 'Finance': 'Business', 'Mechanical Engineering': 'Engineering', 'Chicano Studies': 'Sociology', 'Environ. & Natural Resources': 'Other', 'Industrial Design': 'Engineering', 'Speech & Hearing Sciences': 'Communication', 'Russian': 'Languages', ' ...

# %%
## add a another columns in train `dept_group` 
train['dept_group'] = train['dept'].map(dept_mapping)

# %%
## Now let's see how many sample each dept_group contains
for each_dept in train.dept_group.unique():
    print each_dept, ':', train.ix[train.dept_group == each_dept].shape[0]
# Out:
# Business : 5381
# Economics : 4938
# Religion : 10414
# Sociology : 5910
# Anthropology : 1953
# Accounting : 1764
# Music : 1446
# Psychology : 5042
# Chemistry : 9343
# Arts : 3978
# Biology : 8678
# History : 4822
# Political Science : 4856
# Science : 5827
# Humanities : 1829
# Mathmatics : 10070
# Agriculture and Food Sciences : 610
# Languages : 4209
# Physics : 3509
# Communication : 3614
# nan : 0
# Computer Science : 2465
# English : 6637
# Engineering : 3295
# Education : 1322
# Health Science : 1544
# Literature : 1778
# Other : 632
# Law : 449

# %% [markdown]
# From above result, we can see that the sample for each category is still too little, compared to 2000+ features (words). In this case, we would like to further group the departmenets together

# %%
# use 'group depts v2.txt' to  create a department mapping dictionary
dept_mapping = {}
f = open("group depts v2.txt")
for line in f:
    temp_div = line.split(': ')
    dept_group = temp_div[0]
    temp_depts = temp_div[1].strip('\n')
    for temp_dept in temp_depts.split(', '):
        dept_mapping[temp_dept] = dept_group
f.close()

# %%
## add a another columns in train `dept_group` 
train['dept_group'] = train['dept'].map(dept_mapping)

# %%
## Now let's see how many sample each dept_group contains
for each_dept in train.dept_group.unique():
    print each_dept, ':', train.ix[train.dept_group == each_dept].shape[0]
# Out:
# Business&Economics&Accounting : 12532
# Religion&Philosophy : 11858
# Humanity&Sociology&Psychology : 14734
# Literature&Art&Music : 31340
# Science : 18679
# Bio&Health : 10222
# Mathmatics : 10070
# Other : 2564
# Engineering : 5760
# nan : 0

# %%
temp_word_df = doc_word_df[train.dept_group == 'Engineering']

# %%
print temp_word_df.columns[temp_word_df.sum()==2]
del temp_word_df
# Out:
# Index([u'121', u'75', u'accounting', u'adorable', u'always interesting',
#        u'appreciated', u'articles', u'awful teacher', u'beginning semester',
#        u'best math', u'biased', u'bomb', u'book just', u'boring tests',
#        u'buying', u'church', u'clicker', u'cumulative', u'daily quizzes',
#        u'drops', u'easy pay', u'eyes', u'favorite semester', u'fill',
#        u'french', u'fun listen', u'fun really', u'get just', u'get little',
#        u'go get', u'go read', u'go ta', u'good ta', u'grammar',
#        u'however tests', u'imagine', u'interesting easy',
#        u'interesting listen', u'interesting take', u'just pay', u'just want',
#        u'keeps things', u'know exactly', u'know lot', u'know students',
#        u'know study', u'knows much', u'lecture interesting', u'lecture take',
#        u'lectures always', u'lectures entertaining', u'lectures long',
#        u'level course', u'liberal', u'lot good', u'lot really',
#        u'lots reading', u'loved brother', u'loved professor', u'loving',
#        u'movie', u'never boring', u'notes fine', u'old exams',
#        u'online quizzes', u'power points', u'questions come',
#        u'questions test', u'quiz every', u'quiz questions', u'quizzes every',
#        u'quizzes hard', u'reading assignments', u'realized', u'really made',
#        u'really passionate', u'review sheet', u'sad', u'saved', u'seminar',
#        u'short answer', u'sincere', u'social', u'solely', u'study study',
#        u'super funny', u'sweetest', u'take regret', u'teacher campus',
#        u'teacher made', u'test hard', u'tests super', u'throughout semester',
#        u'two tests', u'understand tests', u'will tests', u'wish take',
#        u'witty'],
#       dtype='object')

# %%
## drop 'comments' column from train data to save some space
print train.columns
train.drop(['comments', 'date', 'tags', 'textbookuse', 'attendance', 'date', 'forcredit'], axis = 1, inplace = True)
print 'after dropping: \n', train.columns
# Out:
# Index([u'id', u'tid', u'dept', u'date', u'forcredit', u'attendance',
#        u'textbookuse', u'interest', u'grade', u'tags', u'comments',
#        u'helpcount', u'nothelpcount', u'online', u'profgender', u'profhotness',
#        u'helpfulness', u'clarity', u'easiness', u'quality', u'dept_group'],
#       dtype='object')
# after dropping:
# Index([u'id', u'tid', u'dept', u'interest', u'grade', u'helpcount',
#        u'nothelpcount', u'online', u'profgender', u'profhotness',
#        u'helpfulness', u'clarity', u'easiness', u'quality', u'dept_group'],
#       dtype='object')

# %% [markdown]
# ### Lasso regression to find the most relavent words for best and worst ratings
#
# The reason to use lasso regression is that I think the input data is highly sparse.

# %% [markdown]
# First, let me test with `Bio&Health` data.

# %%
temp_train = train.ix[train.dept_group == 'Other']
temp_word_df = doc_word_df[train.dept_group == 'Other']
print temp_train.shape, temp_word_df.shape
# Out:
# (2564, 15) (2564, 2849)

# %%
## For temp_word_df, there must be columns that is all-zero, remove those columns
columns = temp_word_df.columns[temp_word_df.sum() == 0]
print columns
temp_word_df.drop(columns, axis = 1, inplace = True)
print temp_word_df.shape
# Out:
# Index([u'103', u'105', u'121', u'202', u'80', u'95', u'absolutely love',
#        u'accounting', u'almost impossible', u'amount reading',
#        ...
#        u'tests multiple', u'tests straight', u'tests straightforward',
#        u'texts', u'throws', u'time tests', u'unrelated', u'uplifting',
#        u'went lecture', u'went office'],
#       dtype='object', length=140)
# (2564, 2709)
# c:\Users\Xinyu\Anaconda\lib\site-packages\IPython\kernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## import several modules
from sklearn import linear_model, cross_validation
from sklearn.metrics import mean_squared_error

# %%
## separate data for training and cross validating

Ytrain = np.ravel(temp_train.quality)
Xtr, Xval, Ytr, Yval = cross_validation.train_test_split(np.array(temp_word_df), Ytrain, test_size = 0.25, random_state = 0)

# %%
alpha_values = [0.001, 0.01]

mseTr = np.zeros((len(alpha_values),))
mseVal = np.zeros((len(alpha_values),))

for i, alpha_value in enumerate(alpha_values):
    print 'alpha: ', alpha_value
    m = linear_model.Lasso(alpha = alpha_value)
    m.fit(Xtr, Ytr)
    YhatTr = m.predict(Xtr)
    YhatVal = m.predict(Xval)
    mseTr[i] = mean_squared_error(YhatTr, Ytr)
    mseVal[i] = mean_squared_error(YhatVal, Yval)
    print mseTr[i], mseVal[i]
# Out:
# alpha:  0.001
# 1.30580795341 4.80455002368
# alpha:  0.01
# 3.57077026713 4.01357975782

# %%
# Next, let's systematically cross validate for each dept_group
mseTr = {}
mseVal = {}

alpha_values = [0.000001, 0.00001, 0.0001, 0.001, 0.1, 1, 10]

for each_dept in train.dept_group.unique():
    if train.ix[train.dept_group == each_dept].shape[0] != 0:
        mseTr[each_dept] = {}
        mseVal[each_dept] = {}
        Xtrain = doc_word_df.ix[train.dept_group == each_dept] # need to drop all-zero columns
        columns = Xtrain.columns[Xtrain.sum() == 0]
        # divide data set
        Xtrain = Xtrain.drop(columns, axis = 1, inplace = False)
        Ytrain = np.ravel(train.ix[train.dept_group == each_dept, 'quality'])
        Xtr, Xval, Ytr, Yval = cross_validation.train_test_split(np.array(Xtrain), 
                                                                 Ytrain, 
                                                                 test_size = 0.25, 
                                                                 random_state = 0)
        # Cross validation - tune alpha value
        print 'Department: ', each_dept
        for i, alpha_value in enumerate(alpha_values):
            print '\t alpha: ', alpha_value
            m = linear_model.Lasso(alpha = alpha_value)
            m.fit(Xtr, Ytr)
            YhatTr = m.predict(Xtr)
            YhatVal = m.predict(Xval)
            mseTr_v = mean_squared_error(YhatTr, Ytr)
            mseVal_v = mean_squared_error(YhatVal, Yval)
            mseTr[each_dept][alpha_value] = mseTr_v
            mseVal[each_dept][alpha_value] = mseVal_v
            print '\t\t', mseTr_v, mseVal_v
# Out:
# Department:  Business&Economics&Accounting
# 	 alpha:  1e-06
# 		2.46446910251 4.93032209964
# 	 alpha:  1e-05
# 		2.46488807812 4.87885160351
# 	 alpha:  0.0001
# 		2.4969230673 4.48118901868
# 	 alpha:  0.001
# 		3.08923882695 3.79616548449
# 	 alpha:  0.1
# 		6.39674666917 6.46675850262
# 	 alpha:  1
# 		7.29232824897 7.41598780283
# 	 alpha:  10
# 		7.29232824897 7.41598785656
# Department:  Religion&Philosophy
# 	 alpha:  1e-06
# 		1.82878012557 3.80631720274
# 	 alpha:  1e-05
# 		1.82931066631 3.7414872034
# 	 alpha:  0.0001
# 		1.8658729671 3.31070863167
# 	 alpha:  0.001
# 		2.3725802407 2.8292489604
# 	 alpha:  0.1
# 		5.12237588789 4.88179639644
# 	 alpha:  1
# 		5.53787598214 5.2796645199
# 	 alpha:  10
# 		5.53787598214 5.27966455442
# Department:  Humanity&Sociology&Psychology
# 	 alpha:  1e-06
# 		2.44111484169 4.45030459593
# 	 alpha:  1e-05
# 		2.44145724832 4.41171409928
# 	 alpha:  0.0001
# 		2.46697693492 4.11919015805
# 	 alpha:  0.001
# 		2.98254276835 3.59364556149
# 	 alpha:  0.1
# 		6.12433356669 6.43130467332
# 	 alpha:  1
# 		6.65914838201 6.9897631051
# 	 alpha:  10
# 		6.65914838201 6.98976293953
# Department:  Literature&Art&Music
# 	 alpha:  1e-06
# 		2.79039440653 3.59268181837
# 	 alpha:  1e-05
# 		2.79069972845 3.57698125781
# 	 alpha:  0.0001
# 		2.8116459708 3.46306030196
# 	 alpha:  0.001
# 		3.1568282909 3.39826529292
# 	 alpha:  0.1
# 		5.98089054307 6.03247678077
# 	 alpha:  1
# 		6.36399765821 6.4289627595
# 	 alpha:  10
# 		6.36399765821 6.42896281835
# Department:  Science
# 	 alpha:  1e-06
# 		2.75886731838 4.2152523097
# 	 alpha:  1e-05
# 		2.75921299023 4.18392608125
# 	 alpha:  0.0001
# 		2.78594793528 3.9491316509
# 	 alpha:  0.001
# 		3.26284686739 3.55661661935
# 	 alpha:  0.1
# 		6.51258650424 6.61449351361
# 	 alpha:  1
# 		7.27422075271 7.42128688461
# 	 alpha:  10
# 		7.27422075271 7.42128694718
# Department:  Bio&Health
# 	 alpha:  1e-06
# 		2.19209353591 5.16959869349
# 	 alpha:  1e-05
# 		2.1925780725 5.08758629793
# 	 alpha:  0.0001
# 		2.22863060588 4.51908197041
# 	 alpha:  0.001
# 		2.86965082227 3.69751058241
# 	 alpha:  0.1
# 		6.27202971197 6.36929154575
# 	 alpha:  1
# 		6.84814178348 6.91954242442
# 	 alpha:  10
# 		6.84814178348 6.91954233697
# Department:  Mathmatics
# 	 alpha:  1e-06
# 		2.59851017108 6.30191362652
# 	 alpha:  1e-05
# 		2.59919756629 6.18071695398
# 	 alpha:  0.0001
# 		2.64577146486 5.40715451703
# 	 alpha:  0.001
# 		3.36799772244 4.15018550199
# 	 alpha:  0.1
# 		7.27559850326 7.38165285674
# 	 alpha:  1
# 		8.82469261847 8.98789933401
# 	 alpha:  10
# 		8.82469261848 8.98789951353
# Department:  Other
# 	 alpha:  1e-06
# 		0.185349991639 52.0412951076
# 	 alpha:  1e-05
# 		0.195450525251 34.3757694171
# 	 alpha:  0.0001
# 		0.343343713786 13.696804961
# 	 alpha:  0.001
# 		1.30580795341 4.80455002368
# 	 alpha:  0.1
# 		6.42521395675 6.17598504547
# 	 alpha:  1
# 		6.93134588386 6.68803341436
# 	 alpha:  10
# 		6.93134588386 6.68803358686
# Department:  Engineering
# 	 alpha:  1e-06
# 		1.6623698568 14.0620019448
# 	 alpha:  1e-05
# 		1.66462099311 13.1067647082
# 	 alpha:  0.0001
# 		1.77857238808 8.35359898791
# 	 alpha:  0.001
# 		2.82998998729 4.75767664084
# 	 alpha:  0.1
# 		6.9312023215 6.73883569845
# 	 alpha:  1
# 		8.00160573664 7.69601093556
# 	 alpha:  10
# 		8.00160573664 7.69601100677
# c:\Users\Xinyu\Anaconda\lib\site-packages\sklearn\linear_model\coordinate_descent.py:444: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)

# %% [markdown]
# From above results, we notice that alpha = 0.001 works for all of the dept_group's. Therefore we can just fix alpha value to 0.001.
#
# Next step, we will train the model on whole dataset with alpha = 0.001. After training the model, we are going to save

# %%
for each_dept in train.dept_group.unique():
    if train.ix[train.dept_group == each_dept].shape[0] != 0:
        
        Xtrain = doc_word_df.ix[train.dept_group == each_dept] # need to drop all-zero columns
        columns = Xtrain.columns[Xtrain.sum() == 0]
        # divide data set
        Xtrain = Xtrain.drop(columns, axis = 1, inplace = False)
        Ytrain = np.ravel(train.ix[train.dept_group == each_dept, 'quality'])
        # Lasso regress
        m = linear_model.Lasso(alpha = 0.001)
        m.fit(np.array(Xtrain), Ytrain)
        # sort coefficients
        words_df = pd.DataFrame(data = {'words': Xtrain.columns, 
                                        'coef': m.coef_})
      
        words_df.sort('coef',ascending=False,inplace=True)
        print 'Department: ', each_dept
        print '\t\t Most Posivie: \n',  words_df[:10]
        print '\t\t Most Negative: \n', words_df[-10:]
        pos_words = words_df[:50]
        pos_words = pos_words.rename_axis({'coef': 'pos_coef', 'words': 'pos_words'}, axis = 1)
        neg_words = words_df[-50:]
        neg_words = neg_words.rename_axis({'coef': 'neg_coef', 'words': 'neg_words'}, axis = 1)
        saved_data  = pd.DataFrame(data = {
                'pos_coef': list(pos_words.pos_coef),
                'pos_words': list(pos_words.pos_words),
                'neg_coef': list(neg_words.neg_coef),
                'neg_words': list(neg_words.neg_words)
            })

        saved_data.to_csv(each_dept + '.csv', index = False)
# Out:
# Department:  Business&Economics&Accounting
# 		 Most Posivie:
#           coef         words
# 688   1.201208     excellent
# 758   1.099202     fantastic
# 1746  1.028272   outstanding
# 186   1.003040       awesome
# 588   0.981418     effective
# 91    0.963398       amazing
# 232   0.850389  best teacher
# 2122  0.838585         rocks
# 988   0.719587         great
# 223   0.699297          best
# 		 Most Negative:
#           coef             words
# 2484 -1.187698          terrible
# 192  -1.229235             awful
# 1831 -1.289786              poor
# 180  -1.328896             avoid
# 2655 -1.349817           useless
# 2642 -1.362923       unorganized
# 1183 -1.412557  incomprehensible
# 1148 -1.511784          horrible
# 2636 -1.610192         unhelpful
# 2794 -1.825893             worst
# Department:  Religion&Philosophy
# 		 Most Posivie:
#           coef          words
# 1855  1.195875  pretty boring
# 730   0.825442       fabulous
# 185   0.769818        awesome
# 91    0.746406        amazing
# 679   0.656699      excellent
# 2739  0.656092      wonderful
# 748   0.648258      fantastic
# 222   0.623484           best
# 2100  0.608754          rocks
# 1789  0.583889     phenomenal
# 		 Most Negative:
#           coef            words
# 1007 -1.216316            guest
# 2103 -1.344074             rude
# 1056 -1.392067  hard understand
# 179  -1.427071            avoid
# 1814 -1.433655             poor
# 2661 -1.435078            waste
# 2095 -1.492458       ridiculous
# 191  -1.629752            awful
# 1138 -1.961163         horrible
# 2766 -2.494507            worst
# Department:  Humanity&Sociology&Psychology
# 		 Most Posivie:
#           coef         words
# 1653  1.183014  never boring
# 762   1.071710     fantastic
# 692   0.922512     excellent
# 2769  0.852514     wonderful
# 188   0.843763       awesome
# 92    0.782170       amazing
# 225   0.775619          best
# 1205  0.768433     inspiring
# 2368  0.730288     surprised
# 1672  0.722910        nicest
# 		 Most Negative:
#           coef        words
# 2005 -1.090951        reads
# 1837 -1.092234         poor
# 194  -1.295619        awful
# 1079 -1.332378        hated
# 182  -1.422609        avoid
# 2487 -1.522328     terrible
# 2624 -1.561568      unclear
# 1152 -1.667897     horrible
# 2644 -1.706662  unorganized
# 2796 -1.751087        worst
# Department:  Literature&Art&Music
# 		 Most Posivie:
#           coef       words
# 690   0.973646   excellent
# 759   0.831747   fantastic
# 92    0.818471     amazing
# 188   0.811277     awesome
# 225   0.783457        best
# 2774  0.782483   wonderful
# 2128  0.778610       rocks
# 1810  0.693669  phenomenal
# 1189  0.624312  incredible
# 426   0.583444     coolest
# 		 Most Negative:
#           coef         words
# 530  -1.176924  disorganized
# 2491 -1.177078      terrible
# 2643 -1.200060     unhelpful
# 1658 -1.215680    never take
# 1152 -1.261177      horrible
# 2131 -1.264974          rude
# 415  -1.286171     confusing
# 182  -1.414902         avoid
# 2629 -1.773797       unclear
# 2801 -2.123979         worst
# Department:  Science
# 		 Most Posivie:
#           coef        words
# 691   1.230427    excellent
# 188   1.121030      awesome
# 92    1.049046      amazing
# 2767  1.036588    wonderful
# 1188  1.036273   incredible
# 225   0.813440         best
# 1133  0.798590    hilarious
# 761   0.724008    fantastic
# 1320  0.692875  knows teach
# 990   0.681369        great
# 		 Most Negative:
#           coef                 words
# 194  -1.192562                 awful
# 2126 -1.227073                  rude
# 182  -1.230118                 avoid
# 518  -1.274850  difficult understand
# 2623 -1.307101               unclear
# 2485 -1.353714              terrible
# 2637 -1.386533             unhelpful
# 2643 -1.398846           unorganized
# 1151 -1.554977              horrible
# 2794 -1.655370                 worst
# Department:  Bio&Health
# 		 Most Posivie:
#           coef           words
# 88    1.120159         amazing
# 682   1.098582       excellent
# 181   1.062796         awesome
# 2740  1.013561       wonderful
# 326   0.926283          caring
# 890   0.894043        get know
# 752   0.889513       fantastic
# 223   0.795610  best professor
# 2245  0.776313           steve
# 218   0.764958            best
# 		 Most Negative:
#           coef            words
# 187  -1.177060            awful
# 2241 -1.227781        stay away
# 1059 -1.301615  hard understand
# 2460 -1.332210         terrible
# 2611 -1.357203        unhelpful
# 2617 -1.404638      unorganized
# 1818 -1.431956             poor
# 1139 -1.509290         horrible
# 104  -1.533402  another teacher
# 2767 -1.636790            worst
# Department:  Mathmatics
# 		 Most Posivie:
#           coef        words
# 1169  1.427301   incredible
# 1299  1.367524  knows teach
# 677   1.339614    excellent
# 88    1.241153      amazing
# 415   1.181069      coolest
# 180   1.142457      awesome
# 217   0.998482         best
# 224   0.996324      best ta
# 1757  0.960891      patient
# 1136  0.942854          hot
# 		 Most Negative:
#           coef     words
# 1599 -1.108385   mumbles
# 1132 -1.167628  horrible
# 2609 -1.170007   useless
# 2577 -1.180070   unclear
# 1056 -1.200361    hardly
# 524  -1.214967      drop
# 2088 -1.287556      rude
# 174  -1.374009     avoid
# 1347 -1.688649  lectured
# 2748 -1.965871     worst
# Department:  Other
# 		 Most Posivie:
#           coef          words
# 198   3.166405       bearable
# 779   2.104591        focuses
# 2156  2.008507          stand
# 1720  1.790058    people like
# 796   1.771702           free
# 1741  1.616744       pictures
# 2113  1.525723          sleep
# 2203  1.457711  students like
# 2150  1.320440     spend time
# 275   1.319995       buy book
# 		 Most Negative:
#           coef        words
# 283  -1.926540        calls
# 1510 -1.935402       method
# 2532 -1.981496  unorganized
# 2512 -2.003633      unclear
# 182  -2.140448        awful
# 1757 -2.231105         poor
# 1564 -2.456816         near
# 2680 -2.488257        worst
# 2087 -2.515945       shares
# 620  -2.661626   every test
# Department:  Engineering
# 		 Most Posivie:
#           coef         words
# 180   2.010465  avoid taking
# 2060  1.543651         rocks
# 739   1.473251     fantastic
# 90    1.259828       amazing
# 183   1.231161       awesome
# 669   1.213152     excellent
# 2603  1.186783       wanting
# 445   1.125160          cute
# 2475  1.091822      thorough
# 1924  1.090734          rare
# 		 Most Negative:
#           coef          words
# 1777 -1.247865           poor
# 2612 -1.291834          waste
# 2412 -1.299343       terrible
# 402  -1.357543      confusing
# 2323 -1.419474   take someone
# 2566 -1.420653    unorganized
# 384  -1.478651  communication
# 177  -1.673100          avoid
# 1116 -1.911812       horrible
# 2714 -2.205537          worst
# c:\Users\Xinyu\Anaconda\lib\site-packages\IPython\kernel\__main__.py:16: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
pos_words.reset_index()
neg_words.reset_index()
pd.DataFrame(data = {'pos_coef': list(pos_words.pos_coef)})
# Out:
#     pos_coef
# 0   2.010465
# 1   1.543651
# 2   1.473251
# 3   1.259828
# 4   1.231161
# 5   1.213152
# 6   1.186783
# 7   1.125160
# 8   1.091822
# 9   1.090734
# 10  1.001037
# 11  0.963792
# 12  0.938475
# 13  0.930653
# 14  0.877763
# 15  0.876258
# 16  0.858576
# 17  0.851655
# 18  0.831524
# 19  0.830280
# 20  0.823753
# 21  0.810369
# 22  0.798460
# 23  0.794985
# 24  0.790246
# 25  0.786117
# 26  0.776187
# 27  0.767968
# 28  0.766980
# 29  0.740702
# 30  0.736313
# 31  0.725481
# 32  0.723530
# 33  0.721726
# 34  0.719476
# 35  0.719059
# 36  0.718803
# 37  0.718234
# 38  0.705827
# 39  0.704042
# 40  0.686607
# 41  0.681447
# 42  0.677532
# 43  0.656578
# 44  0.654235
# 45  0.652019
# 46  0.644705
# 47  0.642829
# 48  0.630738
# 49  0.630319

# %%
pos_words.rename_axis({'coef': 'c'}, axis = 1)
# Out:
#              c             words
# 417  -0.760902             costs
# 639  -0.767382     everyone else
# 1709 -0.774033              paid
# 2328 -0.796909       take unless
# 1214 -0.803235             jumps
# 2678 -0.813705       willing put
# 973  -0.832580       great sense
# 1044 -0.833749              hate
# 2568 -0.834151         unrelated
# 956  -0.844216          graduate
# 2533 -0.848540           try get
# 1662 -0.872113       one classes
# 67   -0.891776             allow
# 38   -0.896152          academic
# 2387 -0.899554     teacher tests
# 1639 -0.903635           numbers
# 1940 -0.903840  reading textbook
# 1922 -0.904198            random
# 324  -0.904223             cases
# 1514 -0.909492              mean
# 2086 -0.915004           screwed
# 189  -0.927089             awful
# 1210 -0.965829           johnson
# 2546 -1.035683           unclear
# 2501 -1.037157              told
# 1527 -1.039911              mess
# 2185 -1.043718             stand
# 2011 -1.054684           refuses
# 1036 -1.061171   hard understand
# 826  -1.064070       frustrating
# 1353 -1.073719              left
# 1135 -1.102842              idea
# 2017 -1.111884            relate
# 122  -1.115356        apparently
# 2063 -1.117261              rude
# 134  -1.119314          arrogant
# 2272 -1.152582             sucks
# 2560 -1.183856         unhelpful
# 1149 -1.239560  incomprehensible
# 2578 -1.239927           useless
# 1777 -1.247865              poor
# 2612 -1.291834             waste
# 2412 -1.299343          terrible
# 402  -1.357543         confusing
# 2323 -1.419474      take someone
# 2566 -1.420653       unorganized
# 384  -1.478651     communication
# 177  -1.673100             avoid
# 1116 -1.911812          horrible
# 2714 -2.205537             worst
